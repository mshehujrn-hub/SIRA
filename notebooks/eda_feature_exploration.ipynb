# %%
import sys
import pandas as pd
from pathlib import Path

# %%
from src.data_loader import DataLoader
from src.eda import DataExplorer

# %%
loader = DataLoader()
explorer = DataExplorer()
df = loader.load_data()

# %%
explorer.show_missing_values(df)
# Out:
# report_text    38
# location       21
# reported_by    26
# dtype: int64

# %%
df.duplicated()
# Out:
# incident_id
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 683     True
# 582     True
# 351     True
# 366     True
# 145     True
# Length: 1000, dtype: bool

# %%
df["report_text"]
# Out:
# incident_id
# 1      Pressure leak detected on Pipeline 7 during ro...
# 2                                                    NaN
# 3                                                    NaN
# 4          Smoke observed from electrical control panel.
# 5                                                    NaN
#                              ...
# 683      Small hydraulic fluid leak found beneath crane.
# 582      small hydraulic fluid leak found beneath crane.
# 351    Routine valve maintenance completed without is...
# 366      Unauthorized personnel entered restricted area.
# 145     Corrosion observed on external pipeline coating.
# Name: report_text, Length: 1000, dtype: str

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.describe()
# Out:
#                                             report_text      location  \
# count                                               962           979
# unique                                               38            15
# top     small hydraulic fluid leak found beneath crane.  Flow Station
# freq                                                 75            80
#
#        reported_by  department severity      incident_type report_date  shift  \
# count          974        1000     1000               1000        1000   1000
# unique          15          12       12                 11         499      2
# top          Ahmed  Production   Medium  Equipment Failure  2026-06-13  Night
# freq            77         130      378                206           9    502
#
#           status
# count       1000
# unique         4
# top     Resolved
# freq         261

# %%
df["severity"] = df["severity"].str.lower()

# %%
df.head()
# Out:
#                                                    report_text  \
# incident_id
# 1            pressure leak detected on pipeline 7 during ro...
# 2                                                          NaN
# 3                                                          NaN
# 4                smoke observed from electrical control panel.
# 5                                                          NaN
#
#                         location reported_by       department severity  \
# incident_id
# 1                     Platform B       Aisha  Instrumentation     high
# 2             Compressor Station        Mary        Utilities      low
# 3                      Tank Farm        Mary        Utilities   medium
# 4                       Refinery         Joy       Production     high
# 5            Gas Processing Unit      Samuel       Production   medium
#
#                  incident_type report_date shift  status
# incident_id
# 1                         Leak  2025-09-30   Day    Open
# 2                   Inspection  2025-12-15   Day  Closed
# 3                    Slip/Fall  2025-09-09   Day    Open
# 4                   Electrical  2026-01-22   Day    Open
# 5            Equipment Failure  2025-02-14   Day  Closed

# %%
df.isnull().sum()
# Out:
# report_text      38
# location         21
# reported_by      26
# department        0
# severity          0
# incident_type     0
# report_date       0
# shift             0
# status            0
# dtype: int64

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\msheh\Desktop\SIRA\.venv-1\Scripts\python.exe

# %%
explorer.duplicate_rows(df)
# Out:
# 'number of duplicate rows: 40'

# %%
df.head(10)
# Out:
#                                                    report_text  \
# incident_id
# 1            pressure leak detected on pipeline 7 during ro...
# 2                                                          NaN
# 3                                                          NaN
# 4                smoke observed from electrical control panel.
# 5                                                          NaN
# 6              worker slipped on wet surface near loading bay.
# 7                      oil spill discovered near storage tank.
# 8             corrosion observed on external pipeline coating.
# 9                smoke observed from electrical control panel.
# 10                                                         NaN
#
#                         location reported_by           department severity  \
# incident_id
# 1                     Platform B       Aisha      Instrumentation     high
# 2             Compressor Station        Mary            Utilities      low
# 3                      Tank Farm        Mary            Utilities   medium
# 4                       Refinery         Joy           Production     high
# 5            Gas Processing Unit      Samuel           Production   medium
# 6                   Flow Station    Blessing  Pipeline Operations   medium
# 7                    Wellhead 12        Paul  Pipeline Operations     high
# 8                   Control Room     Chinedu           Electrical   medium
# 9                   Flow Station      Daniel           Electrical     high
# 10            Compressor Station        John          Maintenance   medium
#
#                  incident_type report_date  shift               status
# incident_id
# 1                         Leak  2025-09-30    Day                 Open
# 2                   Inspection  2025-12-15    Day               Closed
# 3                    Slip/Fall  2025-09-09    Day                 Open
# 4                   Electrical  2026-01-22    Day                 Open
# 5            Equipment Failure  2025-02-14    Day               Closed
# 6                    Slip/Fall  2025-10-26  Night             Resolved
# 7                    Oil Spill  2025-11-09  Night             Resolved
# 8                    Corrosion  2025-11-19    Day             Resolved
# 9                   Electrical  2026-03-21  Night             Resolved
# 10           Equipment Failure  2025-03-26  Night  Under Investigation

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\msheh\Desktop\SIRA

# %%
clean_df = pd.read_csv("data/processed/incident_reports_clean.csv")
clean_df.head()
# Out:
#                                          report_text             location  \
# 0  Pressure leak detected on Pipeline 7 during ro...           Platform B
# 1                                                NaN   Compressor Station
# 2                                                NaN            Tank Farm
# 3      Smoke observed from electrical control panel.             Refinery
# 4                                                NaN  Gas Processing Unit
#
#   reported_by       department severity      incident_type report_date shift  \
# 0       Aisha  Instrumentation     High               Leak  2025-09-30   Day
# 1        Mary        Utilities      Low         Inspection  2025-12-15   Day
# 2        Mary        Utilities   Medium          Slip/Fall  2025-09-09   Day
# 3         Joy       Production     High         Electrical  2026-01-22   Day
# 4      Samuel       Production   Medium  Equipment Failure  2025-02-14   Day
#
#    status
# 0    Open
# 1  Closed
# 2    Open
# 3    Open
# 4  Closed
